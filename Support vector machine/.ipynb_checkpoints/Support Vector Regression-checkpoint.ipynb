# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Data/cement_slump.csv')

# %%
df.head()
# Out:
#    Cement   Slag  Fly ash  Water    SP  Coarse Aggr.  Fine Aggr.  SLUMP(cm)  \
# 0   273.0   82.0    105.0  210.0   9.0         904.0       680.0       23.0
# 1   163.0  149.0    191.0  180.0  12.0         843.0       746.0        0.0
# 2   162.0  148.0    191.0  179.0  16.0         840.0       743.0        1.0
# 3   162.0  148.0    190.0  179.0  19.0         838.0       741.0        3.0
# 4   154.0  112.0    144.0  220.0  10.0         923.0       658.0       20.0
#
#    FLOW(cm)  Compressive Strength (28-day)(Mpa)
# 0      62.0                               34.99
# 1      20.0                               41.14
# 2      20.0                               41.81
# 3      21.5                               42.08
# 4      64.0                               26.82

# %%
df.corr()['Compressive Strength (28-day)(Mpa)']
# Out:
# Cement                                0.445656
# Slag                                 -0.331522
# Fly ash                               0.444380
# Water                                -0.254320
# SP                                   -0.037909
# Coarse Aggr.                         -0.160610
# Fine Aggr.                           -0.154532
# SLUMP(cm)                            -0.223499
# FLOW(cm)                             -0.124189
# Compressive Strength (28-day)(Mpa)    1.000000
# Name: Compressive Strength (28-day)(Mpa), dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
X = df.drop('Compressive Strength (28-day)(Mpa)',axis=1)
y = df['Compressive Strength (28-day)(Mpa)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ## For support vector machines it's highly recommend to scale the data.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVR, LinearSVR

# %%
base_model = SVR()

# %%
base_model.fit(scaled_X_train,y_train)
# Out:
# SVR()

# %%
base_preds = base_model.predict(scaled_X_test)

# %% [markdown]
# ## Evalution

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test,base_preds)
# Out:
# 5.236902091259178

# %%
np.sqrt(mean_squared_error(y_test,base_preds))
# Out:
# 6.695914838327133

# %%
y_test.mean()
# Out:
# 36.26870967741935

# %% [markdown]
# # Grid Search to find the better model

# %%
param_grid = {'C':[0.001,0.01,0.1,0.5,1],
             'kernel':['linear','rbf','poly'],
              'gamma':['scale','auto'],
              'degree':[2,3,4],
              'epsilon':[0,0.01,0.1,0.5,1,2]}


# Linear kernel isn't gonna use degree, only poly uses degree in this data set
# Epsilon is the error you're willing to allow per training data

# %%
from sklearn.model_selection import GridSearchCV

# %%
svr = SVR()

# %%
grid = GridSearchCV(svr,param_grid)

# %%
grid.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1], 'degree': [2, 3, 4],
#                          'epsilon': [0, 0.01, 0.1, 0.5, 1, 2],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
grid.best_params_
# Out:
# {'C': 1, 'degree': 2, 'epsilon': 2, 'gamma': 'scale', 'kernel': 'linear'}

# %% [markdown]
# ## predicting the data with the GridSearchCV result

# %%
grid_preds = grid.predict(scaled_X_test)

# %%
mean_absolute_error(y_test,grid_preds)
# Out:
# 2.5128012210762365

# %%
np.sqrt(mean_squared_error(y_test,grid_preds))
# Out:
# 3.178210305119858
