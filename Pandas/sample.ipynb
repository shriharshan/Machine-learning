# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Telecom_Churn.csv")

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
df.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include='object')
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     382-4657                 no              no
# freq     106            1               3010            2411

# %%
df['international plan']
# Out:
# 0        no
# 1        no
# 2        no
# 3       yes
# 4       yes
#        ...
# 3328     no
# 3329     no
# 3330     no
# 3331    yes
# 3332     no
# Name: international plan, Length: 3333, dtype: object

# %%
df[['state','international plan']]
# Out:
#      state international plan
# 0       KS                 no
# 1       OH                 no
# 2       NJ                 no
# 3       OH                yes
# 4       OK                yes
# ...    ...                ...
# 3328    AZ                 no
# 3329    WV                 no
# 3330    RI                 no
# 3331    CT                yes
# 3332    TN                 no
#
# [3333 rows x 2 columns]

# %%
df.state.unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'CO', 'AZ', 'SC',
#        'NE', 'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR',
#        'MI', 'DE', 'UT', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
df[df['international plan'] == 'no']
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 6       MA             121        510     355-9993                 no
# 8       LA             117        408     335-4719                 no
# ...    ...             ...        ...          ...                ...
# 3327    SC              79        415     348-3830                 no
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df.iloc[14]
# Out:
# state                           IA
# account length                  62
# area code                      415
# phone number              366-9238
# international plan              no
# voice mail plan                 no
# number vmail messages            0
# total day minutes            120.7
# total day calls                 70
# total day charge             20.52
# total eve minutes            307.2
# total eve calls                 76
# total eve charge             26.11
# total night minutes          203.0
# total night calls               99
# total night charge            9.14
# total intl minutes            13.1
# total intl calls                 6
# total intl charge             3.54
# customer service calls           4
# churn                        False
# Name: 14, dtype: object

# %%
df.iloc[14,1]
# Out:
# 62

# %%
df.iloc[22:33]
# Out:
#    state  account length  area code phone number international plan  \
# 22    AZ             130        415     358-1958                 no
# 23    SC             111        415     350-2565                 no
# 24    VA             132        510     343-4696                 no
# 25    NE             174        415     331-3698                 no
# 26    WY              57        408     357-3817                 no
# 27    MT              54        408     418-6412                 no
# 28    MO              20        415     353-2630                 no
# 29    HI              49        510     410-7789                 no
# 30    IL             142        415     416-8428                 no
# 31    NH              75        510     370-3359                 no
# 32    LA             172        408     383-1121                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# ...

# %%
df.iloc[5,8]
# Out:
# 98

# %%
state = df.copy()
state.set_index("state",inplace=True)

# %%
state.loc['OH']
# Out:
#        account length  area code phone number international plan  \
# state
# OH                107        415     371-7191                 no
# OH                 84        408     375-9999                yes
# OH                 65        408     336-7600                 no
# OH                 83        415     370-9116                 no
# OH                 63        415     410-3719                yes
# ...               ...        ...          ...                ...
# OH                160        415     337-9326                 no
# OH                 88        408     354-3040                 no
# OH                106        415     352-2270                 no
# OH                 78        408     368-8555                 no
# OH                 96        415     347-6812                 no
#
#       voice mail plan  number vmail messages  total day minutes  \
# state
# OH                yes                     26              161.6
# ...

# %%
df['state'] == 'OH'
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: state, Length: 3333, dtype: bool

# %%
df[df == 'OH']
# Out:
#      state  account length  area code phone number international plan  \
# 0      NaN             NaN        NaN          NaN                NaN
# 1       OH             NaN        NaN          NaN                NaN
# 2      NaN             NaN        NaN          NaN                NaN
# 3       OH             NaN        NaN          NaN                NaN
# 4      NaN             NaN        NaN          NaN                NaN
# ...    ...             ...        ...          ...                ...
# 3328   NaN             NaN        NaN          NaN                NaN
# 3329   NaN             NaN        NaN          NaN                NaN
# 3330   NaN             NaN        NaN          NaN                NaN
# 3331   NaN             NaN        NaN          NaN                NaN
# 3332   NaN             NaN        NaN          NaN                NaN
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df[(df['international plan'] == 'No') & (df['churn']) == False]
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df[(df['international plan'] == 'No') | (df['churn']) == False]
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df.isnull().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3333, step=1)

# %%
df.shape
# Out:
# (3333, 21)

# %%
df.rename(columns={'international plan' : 'International plan'}, inplace = True)

# %%
df
# Out:
#      state  account length  area code phone number International plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['New Column'] = df['total night minutes'] + df['total intl minutes']

# %%
df
# Out:
#      state  account length  area code phone number International plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['New column2'] = df['International plan'] + df['voice mail plan']
df
# Out:
#      state  account length  area code phone number International plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df['New column3'] = df['International plan'] + '/' + df['voice mail plan']
df
# Out:
#      state  account length  area code phone number International plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df1 = pd.DataFrame({'date': ['10012023 4:15:30', '10042023 7:16:04','10062023 9:25:00',
                            '10142023 15:30:50', '10152023 18:15:00'],
                   'sales': [100, 140, 235, 120, 250]})

# %%
df1
# Out:
#                 date  sales
# 0   10012023 4:15:30    100
# 1   10042023 7:16:04    140
# 2   10062023 9:25:00    235
# 3  10142023 15:30:50    120
# 4  10152023 18:15:00    250

# %%
df1.dtypes
# Out:
# date     object
# sales     int64
# dtype: object

# %%
df1['date'] = pd.to_datetime(df1['date'], format='%m%d%Y %H:%M:%S')

# %%
df1
# Out:
#                  date  sales
# 0 2023-10-01 04:15:30    100
# 1 2023-10-04 07:16:04    140
# 2 2023-10-06 09:25:00    235
# 3 2023-10-14 15:30:50    120
# 4 2023-10-15 18:15:00    250

# %%
df.groupby(['area code']).mean()
# Out:
# C:\Users\shrih\AppData\Local\Temp\ipykernel_37572\3110231035.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['area code']).mean()
#            account length  number vmail messages  total day minutes  \
# area code
# 408            101.877088               7.668258         177.175418
# 415            101.068882               8.357704         181.592628
# 510            100.246429               8.019048         178.787619
#
#            total day calls  total day charge  total eve minutes  \
# area code
# 408             100.496420         30.120274         201.284248
# 415             100.576435         30.871335         200.652085
# 510             100.097619         30.394429         201.323929
#
#            total eve calls  total eve charge  total night minutes  \
# ...

# %%
df.groupby(by=["area code"]).sum()
# Out:
# C:\Users\shrih\AppData\Local\Temp\ipykernel_37572\4167943286.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(by=["area code"]).sum()
#            account length  number vmail messages  total day minutes  \
# area code
# 408                 85373                   6426           148473.0
# 415                167269                  13832           300535.8
# 510                 84207                   6736           150181.6
#
#            total day calls  total day charge  total eve minutes  \
# area code
# 408                  84216          25240.79           168676.2
# 415                 166454          51092.06           332079.2
# 510                  84082          25531.32           169112.1
#
#            total eve calls  total eve charge  total night minutes  \
# ...

# %%
df.groupby(['International plan','area code'])
df
# Out:
#      state  account length  area code phone number International plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
df.groupby('area code').agg('International plan')

# %%
import matplotlib.pyplot as plt

# %%
data = [32, 96, 45, 67, 76, 28, 79, 62, 43, 81, 70,
        61, 95, 44, 60, 69, 71, 23, 69, 54, 76, 67,
        82, 97, 26, 34, 18, 16, 59, 88, 29, 30, 66,
        23, 65, 72, 20, 78, 49, 73, 62, 87, 37, 68,
        81, 80, 77, 92, 81, 52, 43, 68, 71, 86]
plt.hist(data) 
plt.show()

# %%
fig = plt.figure()

# %%
# Left, bottom , width, hieght
fig = plt.figure().add_axes(rect=[0,0,1,1])

# %%
fig = plt.figure().add_axes(rect=[0,0,1,0.5])

# %%
fig = plt.figure().add_axes(rect=[0,0,0.5,1])

# %%
fig = plt.figure(figsize=(5,5)).add_axes(rect=[0,0,1,1])

# %%
fig = plt.figure(figsize=(5,5))

# %%
axes1 = fig.add_axes(rect=[0,0,1,1])
axes2 = fig.add_axes(rect=[1.5,0,1,1])

# %%
fig

# %%
axes1.set_title('chart1')
axes2.set_title('chart2')
# Out:
# Text(0.5, 1.0, 'chart2')

# %%
axes1.set_xlabel('X')
axes1.set_ylabel('Y')

axes2.set_xlabel('X')
axes2.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
fig

# %%
plt.subplots(2,2, tight_layout = True)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
plt.subplots(2,2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))
